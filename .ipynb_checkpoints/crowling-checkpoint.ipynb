# %%
import requests as rq

from bs4 import BeautifulSoup

# %%
url="http://openapi.seoul.go.kr:8088/(인증키)/xml/CardSubwayStatsNew/1/5/20151101"
response=rq.get(url)
if response.status_code==200:
    html=response.text
    soup=BeautifulSoup(html,'html.parser')
    print(soup)
else:
    print(response.status_code)
# Out:
# <result><code>INFO-100</code><message><![CDATA[인증키가 유효하지 않습니다.
# 인증키가 없는 경우, 열린 데이터 광장 홈페이지에서 인증키를 신청하십시오.]]></message></result>

# %%
import urllib.request
import json
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt

# %%
url="http://openapi.seoul.go.kr:8088/47645956727279683630546c6d5164/json/CardSubwayStatsNew/1/1000/20220219"

# %%
response=urllib.request.urlopen(url)
json_str=response.read().decode('utf-8')
#json_object:dict타입
#key:CardSubwayStatsNew
#값 여러가지들..
json_object=json.loads(json_str)
print(json_object.values())

df=pd.json_normalize(json_object['CardSubwayStatsNew']['row'])
print(type(df))
print(json_data.head(2))
# Out:
# dict_values([{'list_total_count': 597, 'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'}, 'row': [{'USE_DT': '20220219', 'LINE_NUM': '1호선', 'SUB_STA_NM': '서울역', 'RIDE_PASGR_NUM': 24632.0, 'ALIGHT_PASGR_NUM': 25055.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '1호선', 'SUB_STA_NM': '동묘앞', 'RIDE_PASGR_NUM': 9499.0, 'ALIGHT_PASGR_NUM': 9760.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '1호선', 'SUB_STA_NM': '시청', 'RIDE_PASGR_NUM': 9810.0, 'ALIGHT_PASGR_NUM': 10057.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '1호선', 'SUB_STA_NM': '종각', 'RIDE_PASGR_NUM': 16290.0, 'ALIGHT_PASGR_NUM': 15067.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '1호선', 'SUB_STA_NM': '종로3가', 'RIDE_PASGR_NUM': 18911.0, 'ALIGHT_PASGR_NUM': 18508.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '1호선', 'SUB_STA_NM': '종로5가', 'RIDE_PASGR_NUM': 16085.0, 'ALIGHT_PASGR_NUM': 16086.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '1호선', 'SUB_STA_NM': '동대문', 'RIDE_PASGR_NUM': 9200.0, 'ALIGHT_PASGR_NUM': 8716.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '1호선', 'SUB_STA_NM': '신설동', 'RIDE_PASGR_NUM': 8822.0, 'ALIGHT_PASGR_NUM': 8308.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '1호선', 'SUB_STA_NM': '제기동', 'RIDE_PASGR_NUM': 13304.0, 'ALIGHT_PASGR_NUM': 13292.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '1호선', 'SUB_STA_NM': '청량리(서울시립대입구)', 'RIDE_PASGR_NUM': 15733.0, 'ALIGHT_PASGR_NUM': 15769.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '시청', 'RIDE_PASGR_NUM': 8027.0, 'ALIGHT_PASGR_NUM': 6863.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '을지로입구', 'RIDE_PASGR_NUM': 17207.0, 'ALIGHT_PASGR_NUM': 17005.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '을지로3가', 'RIDE_PASGR_NUM': 9017.0, 'ALIGHT_PASGR_NUM': 8758.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '을지로4가', 'RIDE_PASGR_NUM': 6461.0, 'ALIGHT_PASGR_NUM': 6378.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '동대문역사문화공원(DDP)', 'RIDE_PASGR_NUM': 8238.0, 'ALIGHT_PASGR_NUM': 8961.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '신당', 'RIDE_PASGR_NUM': 9864.0, 'ALIGHT_PASGR_NUM': 10308.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '상왕십리', 'RIDE_PASGR_NUM': 8764.0, 'ALIGHT_PASGR_NUM': 8547.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '왕십리(성동구청)', 'RIDE_PASGR_NUM': 11699.0, 'ALIGHT_PASGR_NUM': 10118.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '한양대', 'RIDE_PASGR_NUM': 3629.0, 'ALIGHT_PASGR_NUM': 3758.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '뚝섬', 'RIDE_PASGR_NUM': 11914.0, 'ALIGHT_PASGR_NUM': 12481.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '성수', 'RIDE_PASGR_NUM': 17901.0, 'ALIGHT_PASGR_NUM': 19583.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '건대입구', 'RIDE_PASGR_NUM': 29910.0, 'ALIGHT_PASGR_NUM': 31115.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '구의(광진구청)', 'RIDE_PASGR_NUM': 14825.0, 'ALIGHT_PASGR_NUM': 14650.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '강변(동서울터미널)', 'RIDE_PASGR_NUM': 22124.0, 'ALIGHT_PASGR_NUM': 21717.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '잠실나루', 'RIDE_PASGR_NUM': 6329.0, 'ALIGHT_PASGR_NUM': 6258.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '잠실(송파구청)', 'RIDE_PASGR_NUM': 51976.0, 'ALIGHT_PASGR_NUM': 49839.0, 'WORK_DT': '20220222'}, {'USE_DT': '20220219', 'LINE_NUM': '2호선', 'SUB_STA_NM': '잠실새내', 'RIDE_PASGR_NUM': 14739.0, 'ALIGHT_PASGR_NUM': 15123.0, 'WORK_DT': '20220222'}, {'USE_DT ...
# <class 'pandas.core.frame.DataFrame'>
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
print(1)
# Out:
# 1
